# %% [markdown]
# # Before you start :
#    - These exercises are related to the Pivot table and correlation lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# your answer here
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Open the ` Employee.csv` file and name your dataset `employee`.

# %%
# your answer here
employee = pd.read_csv("C:\\Users\\carmo\\Desktop\\IronHack\\Week 13\\Day 1\\lab-pivot-table-correlation\\your_code\\data\\Employee.csv")

# %% [markdown]
# #### What's the mean salary by department?
# Hint : There are 2 ways to do it - one way is with groupby and the other way is with pivot tables. Do it both ways.

# %%
# Method 1
## Calculate the mean salary by department using groupby
mean_salary_groupby = employee.groupby('Department')['Salary'].mean()

mean_salary_groupby
# Out:
# Department
# HR       45.00
# IT       48.75
# Sales    55.00
# Name: Salary, dtype: float64

# %%
# Method 2
# your answer here
# Calculate the mean salary by department using pivot_table
mean_salary_pivot = employee.pivot_table(values='Salary', index='Department', aggfunc='mean')

mean_salary_pivot
# Out:
#             Salary
# Department
# HR           45.00
# IT           48.75
# Sales        55.00

# %% [markdown]
# #### We want now to group the data by more than one column. Use Pandas pivot table function to select the mean salary by department and title.

# %%
# your answer here
# Calculate the mean salary by department and title using pivot_table
mean_salary_by_dept_title = employee.pivot_table(values='Salary', index=['Department', 'Title'], aggfunc='mean')

mean_salary_by_dept_title
# Out:
#                       Salary
# Department Title
# HR         VP           70.0
#            analyst      32.5
# IT         VP           70.0
#            analyst      32.5
#            associate    60.0
# Sales      associate    55.0

# %% [markdown]
# #### We want to display the number of years of work experience and the salary for each Title. Add Years as a column in your pivot table.
# *Hint: Use Pandas doc(see References in README.md) to explore the pivot_table() arguments*

# %%
# your answer here
# Create a pivot table with both 'Years' and 'Salary' for each 'Title'
pivot_table_years_salary = employee.pivot_table(values=['Years', 'Salary'], index='Title', aggfunc='mean')

pivot_table_years_salary
# Out:
#               Salary  Years
# Title
# VP         70.000000   8.00
# analyst    32.500000   2.25
# associate  56.666667   4.00

# %% [markdown]
# #### We want to know the information about the mean salary and number of employees in each department and for each job title.

# %%
# your answer here
# Create a pivot table with mean 'Salary' and count of 'Name' for each combination of 'Department' and 'Title'
pivot_table_salary_count = employee.pivot_table(values=['Salary', 'Name'], 
                                                index=['Department', 'Title'], 
                                                aggfunc={'Salary': 'mean', 'Name': 'count'})

# Rename the 'Name' column to 'Number of Employees'
pivot_table_salary_count.rename(columns={'Name': 'Number of Employees'}, inplace=True)

pivot_table_salary_count
# Out:
#                       Number of Employees  Salary
# Department Title
# HR         VP                           1    70.0
#            analyst                      2    32.5
# IT         VP                           1    70.0
#            analyst                      2    32.5
#            associate                    1    60.0
# Sales      associate                    2    55.0

# %% [markdown]
# #### We want to know for each department and for each job title the Salary's median, minimum, maximum and standard deviation. Comment your results.

# %%
# your answer here
# Create a pivot table with median, min, max, and std of 'Salary' for each combination of 'Department' and 'Title'
pivot_table_salary_stats = employee.pivot_table(values='Salary', 
                                                index=['Department', 'Title'], 
                                                aggfunc=['median', 'min', 'max', 'std'])

pivot_table_salary_stats
# Out:
#                      median    min    max       std
#                      Salary Salary Salary    Salary
# Department Title
# HR         VP          70.0     70     70       NaN
#            analyst     32.5     30     35  3.535534
# IT         VP          70.0     70     70       NaN
#            analyst     32.5     30     35  3.535534
#            associate   60.0     60     60       NaN
# Sales      associate   55.0     55     55  0.000000

# %% [markdown]
# Wherever the standard deviation (std) is NaN, it means there's only one employee in that specific combination of department and title. Since standard deviation requires at least two data points to be computed, it's not defined for single data points.
# For the Sales department associates, even though there are two employees, their salaries are identical, leading to a standard deviation of $0.00.
# The minimum and maximum values being the same in some cases further highlight that there's either only one employee or all employees in that group have the same salary.
# Filling Missing Values:

# %% [markdown]
# #### Based on your comments, fill the missing values with an appropriate value.

# %%
# your answer here
# Fill NaN values in the standard deviation column with 0
pivot_table_salary_stats['std', 'Salary'].fillna(0, inplace=True)

pivot_table_salary_stats
# Out:
#                      median    min    max       std
#                      Salary Salary Salary    Salary
# Department Title
# HR         VP          70.0     70     70  0.000000
#            analyst     32.5     30     35  3.535534
# IT         VP          70.0     70     70  0.000000
#            analyst     32.5     30     35  3.535534
#            associate   60.0     60     60  0.000000
# Sales      associate   55.0     55     55  0.000000

# %% [markdown]
# #### The stake holders want to know for each department the number of employees and how much money is spend on salaries. Could you provide that information?

# %%
# your answer here
# Create a pivot table to count the number of employees and sum the salaries for each department
pivot_table_employee_costs = employee.pivot_table(values=['Name', 'Salary'], 
                                                  index='Department', 
                                                  aggfunc={'Name': 'count', 'Salary': 'sum'})

# Rename the columns for clarity
pivot_table_employee_costs.rename(columns={'Name': 'Number of Employees', 'Salary': 'Total Salary Expenditure'}, inplace=True)

pivot_table_employee_costs
# Out:
#             Number of Employees  Total Salary Expenditure
# Department
# HR                            3                       135
# IT                            4                       195
# Sales                         2                       110

# %% [markdown]
# #### For each Department and Title, we want to know the the total years of work experience and the mean salary.

# %%
# your answer here
# Create a pivot table for total years of work experience and mean salary by Department and Title
pivot_table_experience_salary = employee.pivot_table(values=['Years', 'Salary'], 
                                                     index=['Department', 'Title'], 
                                                     aggfunc={'Years': 'sum', 'Salary': 'mean'})

pivot_table_experience_salary.rename(columns={'Years': 'Total Years of Experience', 'Salary': 'Mean Salary'}, inplace=True)

pivot_table_experience_salary
# Out:
#                       Mean Salary  Total Years of Experience
# Department Title
# HR         VP                70.0                          8
#            analyst           32.5                          6
# IT         VP                70.0                          8
#            analyst           32.5                          3
#            associate         60.0                          7
# Sales      associate         55.0                          5

# %% [markdown]
# ### Bonus
#
# #### We now want to compute the mean salary after removing the maxima for each Department. Create the appropriate pivot table.
#
# Hint: Write a custom function.

# %%
# your answer here
# Custom function to compute mean salary after excluding the maximum salary for each group
def mean_excluding_max(salary_series):
    return salary_series[salary_series != salary_series.max()].mean()

# Create a pivot table using the custom function for each Department
pivot_table_mean_excluding_max = employee.pivot_table(values='Salary', 
                                                      index='Department', 
                                                      aggfunc=mean_excluding_max)

pivot_table_mean_excluding_max.rename(columns={'Salary': 'Mean Salary Excluding Max'}, inplace=True)

pivot_table_mean_excluding_max
# Out:
#             Mean Salary Excluding Max
# Department
# HR                          32.500000
# IT                          41.666667

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Open the ` Fitbit.csv` file and name your dataset `fitbit`.

# %%
# your answer here
fitbit = pd.read_csv("C:\\Users\\carmo\\Desktop\\IronHack\\Week 13\\Day 1\\lab-pivot-table-correlation\\your_code\\data\\Fitbit.csv")

# %% [markdown]
# #### Explore you dataset in terms of data types and descriptive statistics.
# Hint: Use Pandas functions from previous lectures.

# %%
# your answer here
# Display the data types of each column
data_types = fitbit.dtypes
data_types
# Out:
# Date                       object
# Calorie burned              int64
# Steps                       int64
# Distance                  float64
# Floors                      int64
# Minutes Sedentary         float64
# Minutes Lightly Active      int64
# Minutes Fairly Active       int64
# Minutes Very Active         int64
# Activity Calories           int64
# MinutesOfSleep              int64
# MinutesOfBeingAwake         int64
# NumberOfAwakings            int64
# LengthOfRestInMinutes       int64
# dtype: object

# %%
# your answer here
# Display descriptive statistics for the dataset
descriptive_stats = fitbit.describe()

descriptive_stats
# Out:
#        Calorie burned         Steps    Distance      Floors  \
# count      367.000000    367.000000  367.000000  367.000000
# mean      2741.501362  10121.588556    8.549128   11.724796
# std        916.307036   5594.836225    3.409881   10.337370
# min        179.000000      0.000000    0.000000    0.000000
# 25%       2698.000000   6730.500000    6.155000    5.000000
# 50%       2974.000000  10413.000000    8.290000   11.000000
# 75%       3233.000000  13916.500000   10.560000   16.000000
# max       4351.000000  26444.000000   20.450000  101.000000
#
#        Minutes Sedentary  Minutes Lightly Active  Minutes Fairly Active  \
# count         367.000000              367.000000             367.000000
# mean          563.934482              236.405995              26.163488
# std           294.793145               86.531376              20.319456
# min             1.002000                0.000000               0.000000
# ...

# %% [markdown]
# #### You suspect that there must be a linear relationship between the Minutes Very Active and the Steps. Compute the correlation between these variables.

# %%
# your answer here
# Compute the correlation between 'Minutes Very Active' and 'Steps'
correlation = fitbit['Minutes Very Active'].corr(fitbit['Steps'])

correlation
# Out:
# 0.5714518481062608

# %% [markdown]
# #### Use matplotlib to visually plot Minutes Very active vs Steps.
#
# ##### Hint : import matplotlib.pyplot as plt (See previous lessons)#####
# - Use plt.scatter(x=df['col_name_1'], y=df['col_name_2'])

# %%
# your answer here
# Scatter plot for 'Minutes Very Active' vs 'Steps'
plt.figure(figsize=(10, 6))
plt.scatter(x=fitbit['Minutes Very Active'], y=fitbit['Steps'], color='blue', alpha=0.6)
plt.title('Minutes Very Active vs Steps')
plt.xlabel('Minutes Very Active')
plt.ylabel('Steps')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# #### What can you say about Minute Very Active and Steps? Write a comment below

# %% [markdown]
# # Comments
# The scatter plot and the correlation coefficient of approximately 0.5715 suggest a moderate positive linear relationship between "Minutes Very Active" and "Steps". As the number of minutes an individual is very active increases, there tends to be an increase in the number of steps recorded. However, the relationship isn't extremely tight. The spread of data points in the scatter plot, especially at lower minutes of activity, indicates that there's variability in the number of steps taken even when the activity is low. This suggests that while very active minutes contribute to step count, other activities or factors also influence the total steps taken.

# %% [markdown]
# #### We also suspect that there must be a linear relationship between the Minutes Sedentary and the Steps. Compute the correlation between these variables.

# %%
# your answer here
# Compute the correlation between 'Minutes Sedentary' and 'Steps'
correlation_sedentary_steps = fitbit['Minutes Sedentary'].corr(fitbit['Steps'])

correlation_sedentary_steps
# Out:
# 0.07690608062990091

# %% [markdown]
# #### Use matplotlib to visually plot Minutes Sedentary vs Steps. Based on the results of the computed correlation and the plot. What can you say about these 2 variables?

# %%
# your answer here
# Scatter plot for 'Minutes Sedentary' vs 'Steps'
plt.figure(figsize=(10, 6))
plt.scatter(x=fitbit['Minutes Sedentary'], y=fitbit['Steps'], color='red', alpha=0.6)
plt.title('Minutes Sedentary vs Steps')
plt.xlabel('Minutes Sedentary')
plt.ylabel('Steps')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# # Comments
# From the scatter plot and the very low correlation coefficient of approximately 0.0769, it's evident that there's a weak association between "Minutes Sedentary" and "Steps". The scatter plot shows a broad spread of data points without a clear trend. While there's a slight positive correlation, it's not substantial enough to make meaningful inferences.
#
# In essence, the amount of time a person is sedentary doesn't significantly impact their step count. This is intuitive because being sedentary implies inactivity, and therefore, it wouldn't be strongly correlated with an activity metric like steps.

# %% [markdown]
# #### We also suspect that there must be a linear relationship between the MinutesOfSleep and the Steps. Compute the correlation between these variables.

# %%
# your answer here
# Compute the correlation between 'MinutesOfSleep' and 'Steps'
correlation_sleep_steps = fitbit['MinutesOfSleep'].corr(fitbit['Steps'])

correlation_sleep_steps
# Out:
# 0.1309856595083638

# %% [markdown]
# #### Use matplotlib to visually plot MinutesOfSleep vs Steps. Based on the results of the computed correlation and the plot. What can you say about these 2 variables?

# %%
# your answer here
# Scatter plot for 'MinutesOfSleep' vs 'Steps'
plt.figure(figsize=(10, 6))
plt.scatter(x=fitbit['MinutesOfSleep'], y=fitbit['Steps'], color='green', alpha=0.6)
plt.title('Minutes of Sleep vs Steps')
plt.xlabel('Minutes of Sleep')
plt.ylabel('Steps')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# # Comments
# From the scatter plot and the correlation coefficient of approximately 0.1310, it's clear that there's a weak positive association between "MinutesOfSleep" and "Steps". The scatter plot shows a spread of data points without a distinct trend, reinforcing the idea that the two variables aren't strongly related. While there's a slight tendency for individuals with more sleep minutes to have a higher step count, it's not a strong or consistent pattern.
#
# In essence, the amount of sleep a person gets does not significantly impact their daily step count. This suggests that factors other than sleep duration play a more pivotal role in determining daily activity levels.

# %% [markdown]
# #### Select a subset of your dataset with the columns below and compute the correlation matrix. Save the results in the variable `cor_fit`
# column= ['Calorie burned', 'Steps','Floors','Minutes Sedentary','Minutes Very Active', 'MinutesOfSleep']

# %%
# your answer here
# Select a subset of the dataset with the specified columns
subset = fitbit[['Calorie burned', 'Steps', 'Floors', 'Minutes Sedentary', 'Minutes Very Active', 'MinutesOfSleep']]

# Compute the correlation matrix
cor_fit = subset.corr()

# Select the 'Steps' row from the correlation matrix and order the results in descending order
correlation_with_steps = cor_fit['Steps'].sort_values(ascending=False)

correlation_with_steps
# Out:
# Steps                  1.000000
# Minutes Very Active    0.571452
# Floors                 0.306511
# Calorie burned         0.255305
# MinutesOfSleep         0.130986
# Minutes Sedentary      0.076906
# Name: Steps, dtype: float64

# %% [markdown]
# #### Based on the result of the correlation matrix. What are the highly correlated features with the variable Steps?
# *Hint: From the results above select the variable Steps and order your results in descending order (use Pandas sort_values function)*

# %% [markdown]
# # Comments:
#
# The feature that has the strongest correlation with "Steps" is "Minutes Very Active", which is intuitive. The more active someone is, the more steps they're likely to take.
# "Floors" and "Calorie burned" also have a positive correlation with "Steps", though the relationships are weaker.
# "MinutesOfSleep" and "Minutes Sedentary" have very weak positive correlations with "Steps", suggesting that these variables don't significantly influence the step count.
# In conclusion, among the selected features, "Minutes Very Active" is the most correlated with "Steps", followed by "Floors" and "Calorie burned".

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the `Time_Grades.csv` file and name your dataset `time_grades`.

# %%
# your answer here
time_grades = pd.read_csv("C:\\Users\\carmo\\Desktop\\IronHack\\Week 13\\Day 1\\lab-pivot-table-correlation\\your_code\\data\\Time_Grades.csv")

# %% [markdown]
# #### Show visually the frequency distribution of the time_grades dataset.

# %%
# your answer here
# Set up the figure and axes
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15, 6))

# Plot the frequency distribution for 'Study time'
ax[0].hist(time_grades['Study time'], bins=10, color='blue', alpha=0.7)
ax[0].set_title('Frequency Distribution of Study Time')
ax[0].set_xlabel('Study Time')
ax[0].set_ylabel('Frequency')
ax[0].grid(True, which='both', linestyle='--', linewidth=0.5)

# Plot the frequency distribution for 'Grade'
ax[1].hist(time_grades['Grade'], bins=10, color='green', alpha=0.7)
ax[1].set_title('Frequency Distribution of Grade')
ax[1].set_xlabel('Grade')
ax[1].set_ylabel('Frequency')
ax[1].grid(True, which='both', linestyle='--', linewidth=0.5)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Is there a correlation between study time and Grade? Use both Pearson and Spearman correlation and comment your results.

# %%
# your answer here
# Compute Pearson and Spearman correlation between 'Study time' and 'Grade'
pearson_correlation = time_grades['Study time'].corr(time_grades['Grade'], method='pearson')
spearman_correlation = time_grades['Study time'].corr(time_grades['Grade'], method='spearman')

pearson_correlation, spearman_correlation
# Out:
# (0.7980456073578858, 0.819658753036942)

# %% [markdown]
# Comments:
#
# Pearson Correlation: This measures the linear relationship between two variables. A value of
# 0.7980
# 0.7980 indicates a strong positive linear relationship between study time and grade. As the study time increases, the grade tends to increase as well.
# Spearman Correlation: This measures the monotonic relationship between two variables. A value of
# 0.8197
# 0.8197 suggests a strong positive monotonic relationship between study time and grade. Even if the relationship isn't perfectly linear, as one variable increases, the other tends to increase.
# Both correlation measures point to a strong positive association between study time and grade. This implies that students who invest more time in studying generally achieve higher grades, although other factors might also influence grades. The slight difference between the Pearson and Spearman values suggests that while the relationship is largely linear, there might be some non-linear aspects to it.

# %% [markdown]
# #### Use matplotlib to visually plot Study time vs Grade. Based on the results of the computed correlation and the plot. What can you say about these 2 variables?

# %%
# your answer here
# Scatter plot for 'Study time' vs 'Grade'
plt.figure(figsize=(10, 6))
plt.scatter(time_grades['Study time'], time_grades['Grade'], color='purple', alpha=0.6)
plt.title('Study Time vs Grade')
plt.xlabel('Study Time')
plt.ylabel('Grade')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# Comments on "Study Time" vs "Grade" Plot:
# The scatter plot visually confirms the positive relationship between study time and grade, which was indicated by both the Pearson and Spearman correlation coefficients. As study time increases, grades generally tend to be higher. The data points seem to follow a general upward trend, suggesting that more study time is associated with better performance.

# %% [markdown]
# #### Could you explain the difference between Pearson and Spearman correlation? (see References in README.md)

# %% [markdown]
# # Difference between Pearson and Spearman Correlation:
#
# Pearson Correlation:
#
# Type: It measures the linear relationship between two variables.
# Assumptions: It assumes that both variables are normally distributed and have a linear relationship.
# Sensitivity: It's sensitive to outliers. An outlier can drastically change the Pearson correlation value.
# Usage: It's most appropriate when the relationship between variables is linear, and the data doesn't have significant outliers.
# Spearman Correlation:
#
# Type: It measures the monotonic relationship between two variables, whether linear or not.
# Assumptions: It doesn't assume that the data is normally distributed.
# Sensitivity: It's less sensitive to outliers compared to Pearson.
# Usage: It's most appropriate when the relationship between variables is non-linear or when the data contains outliers.
# In essence, while both correlations measure the strength and direction of a relationship between two variables, Pearson focuses on linear relationships, whereas Spearman can capture non-linear monotonic relationships.
