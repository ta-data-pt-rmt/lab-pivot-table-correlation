# %% [markdown]
# # Before you start :
#    - These exercises are related to the Pivot table and correlation lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# your answer here
import pandas as pd
employees=pd.read_csv("/Users/nhannguyen/Desktop/Ironhack/Week_12/lab-pivot-table-correlation/your_code/data/Employee.csv")
fitbit=pd.read_csv("/Users/nhannguyen/Desktop/Ironhack/Week_12/lab-pivot-table-correlation/your_code/data/Fitbit.csv")
grades=pd.read_csv("/Users/nhannguyen/Desktop/Ironhack/Week_12/lab-pivot-table-correlation/your_code/data/Time_Grades.csv")

# %% [markdown]
# # Challenge 1

# %% [markdown]
# #### Open the ` Employee.csv` file and name your dataset `employee`.

# %%
# your answer here
employees.head(5)
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55

# %% [markdown]
# #### What's the mean salary by department?
# Hint : There are 2 ways to do it - one way is with groupby and the other way is with pivot tables. Do it both ways.

# %%
# Groupy
# Group by department and calculate mean salary
mean_salary_by_department = employees.groupby('Department')['Salary'].mean()

print(mean_salary_by_department)

# import numpy as np
# # Group by department and get the salary column as a NumPy array
# grouped_by_department = employees.groupby('department')['salary']

# # Calculate mean salary using NumPy
# mean_salary_by_department = grouped_by_department.apply(np.mean)

# print(mean_salary_by_department)
# Out:
# Department
# HR       45.00
# IT       48.75
# Sales    55.00
# Name: Salary, dtype: float64

# %%
# Pivot


# Create a pivot table to calculate mean salary by department
mean_salary_by_department = pd.pivot_table(employees, values='Salary', index='Department', aggfunc='mean')

print(mean_salary_by_department)
# Out:
#             Salary
# Department
# HR           45.00
# IT           48.75
# Sales        55.00

# %% [markdown]
# #### We want now to group the data by more than one column. Use Pandas pivot table function to select the mean salary by department and title.

# %%
# Create a pivot table to calculate mean salary by department and title
mean_salary_by_department_title = pd.pivot_table(employees, values='Salary', index=['Department', 'Title'], aggfunc='mean')

print(mean_salary_by_department_title)
# Out:
#                       Salary
# Department Title
# HR         VP           70.0
#            analyst      32.5
# IT         VP           70.0
#            analyst      32.5
#            associate    60.0
# Sales      associate    55.0

# %% [markdown]
# #### We want to display the number of years of work experience and the salary for each Title. Add Years as a column in your pivot table.
# *Hint: Use Pandas doc(see References in README.md) to explore the pivot_table() arguments*

# %%
# Create a pivot table to calculate mean salary and include years of experience
mean_salary_by_department_title = pd.pivot_table(employees, values=['Salary', 'Years'], index=['Department', 'Title'], aggfunc={'Salary': 'mean', 'Years': 'mean'})

print(mean_salary_by_department_title)
# Out:
#                       Salary  Years
# Department Title
# HR         VP           70.0    8.0
#            analyst      32.5    3.0
# IT         VP           70.0    8.0
#            analyst      32.5    1.5
#            associate    60.0    7.0
# Sales      associate    55.0    2.5

# %% [markdown]
# #### We want to know the information about the mean salary and number of employees in each department and for each job title.

# %%
# Create a pivot table with multiple aggregations
pivot_table_result = pd.pivot_table(employees, 
                                    values=['Salary', 'Name'], 
                                    index=['Department', 'Title'], 
                                    aggfunc={'Salary': 'mean', 'Name': 'count'})

# Rename the columns for clarity
pivot_table_result.columns = ['mean_salary', 'num_employees']

print(pivot_table_result)
# Out:
#                       mean_salary  num_employees
# Department Title
# HR         VP                   1           70.0
#            analyst              2           32.5
# IT         VP                   1           70.0
#            analyst              2           32.5
#            associate            1           60.0
# Sales      associate            2           55.0

# %% [markdown]
# #### We want to know for each department and for each job title the Salary's median, minimum, maximum and standard deviation. Comment your results.

# %%
# Create a pivot table with multiple aggregations
pivot_table_result = pd.pivot_table(employees, 
                                    values='Salary', 
                                    index=['Department', 'Title'], 
                                    aggfunc=['median', 'min', 'max', 'std'])

# Rename the columns for clarity
pivot_table_result.columns = ['median_salary', 'min_salary', 'max_salary', 'std_salary']

print(pivot_table_result)
# Out:
#                       median_salary  min_salary  max_salary  std_salary
# Department Title
# HR         VP                  70.0          70          70         NaN
#            analyst             32.5          30          35    3.535534
# IT         VP                  70.0          70          70         NaN
#            analyst             32.5          30          35    3.535534
#            associate           60.0          60          60         NaN
# Sales      associate           55.0          55          55    0.000000

# %%
# # Comments : there is some categories that have only one data point (one employee) for some combinations of department and job title. 
# Hence the standard deviation cannot be calculated because it requires at least two data points

# %% [markdown]
# #### Based on your comments, fill the missing values with an appropriate value.

# %%
# using the skipna=False parameter in the pivot_table function to include NaN values in the result
# Create a pivot table with multiple aggregations and fill NaN values for std with 0
pivot_table_result = pd.pivot_table(employees, 
                                    values='Salary', 
                                    index=['Department', 'Title'], 
                                    aggfunc=['median', 'min', 'max', 'std'])


# Rename the columns for clarity
pivot_table_result.columns = ['median_salary', 'min_salary', 'max_salary', 'std_salary']

# Fill NaN values with 0 for the 'std_salary' column
pivot_table_result['std_salary'] = pivot_table_result['std_salary'].fillna(0)

print(pivot_table_result)
# Out:
#                       median_salary  min_salary  max_salary  std_salary
# Department Title
# HR         VP                  70.0          70          70    0.000000
#            analyst             32.5          30          35    3.535534
# IT         VP                  70.0          70          70    0.000000
#            analyst             32.5          30          35    3.535534
#            associate           60.0          60          60    0.000000
# Sales      associate           55.0          55          55    0.000000

# %% [markdown]
# #### The stake holders want to know for each department the number of employees and how much money is spend on salaries. Could you provide that information?

# %%
# Group by department and calculate the number of employees and total salary expenditure
department_summary = employees.groupby('Department').agg({'Name': 'count', 'Salary': 'sum'})

# Rename the columns for clarity
department_summary.columns = ['num_employees', 'total_salary_expenditure']

print(department_summary)
# Out:
#             num_employees  total_salary_expenditure
# Department
# HR                      3                       135
# IT                      4                       195
# Sales                   2                       110

# %% [markdown]
# #### For each Department and Title, we want to know the the total years of work experience and the mean salary.

# %%
# Create a pivot table with multiple aggregations
pivot_table_result = pd.pivot_table(employees, 
                                    values=['Salary', 'Years'], 
                                    index=['Department', 'Title'], 
                                    aggfunc={'Salary': 'mean', 'Years': 'sum'})

# Rename the columns for clarity
pivot_table_result.columns = ['mean_salary', 'sum_exp']

print(pivot_table_result)
# Out:
#                       mean_salary  sum_exp
# Department Title
# HR         VP                70.0        8
#            analyst           32.5        6
# IT         VP                70.0        8
#            analyst           32.5        3
#            associate         60.0        7
# Sales      associate         55.0        5

# %% [markdown]
# ### Bonus
#
# #### We now want to compute the mean salary after removing the maxima for each Department. Create the appropriate pivot table.
#
# Hint: Write a custom function.

# %%
# Identify the maximum salary within each department
max_salaries = employees.groupby('Department')['Salary'].transform('max')

# Mark rows where the salary is equal to the maximum salary within the department
employees['is_max_salary'] = employees['Salary'] == max_salaries

# Create a new DataFrame excluding the rows marked as max salary
filtered_employees = employees[~employees['is_max_salary']].copy()

# Drop the 'is_max_salary' column as it's no longer needed
filtered_employees.drop(columns=['is_max_salary'], inplace=True)

# Create a pivot table to calculate the mean salary after removing the maxima
mean_salary_without_maxima = pd.pivot_table(filtered_employees, 
                                            values='Salary', 
                                            index=['Department', 'Title'], 
                                            aggfunc='mean')

# Rename the columns for clarity
mean_salary_without_maxima.columns = ['mean_salary_without_maxima']

print(mean_salary_without_maxima)
# Out:
#                       mean_salary_without_maxima
# Department Title
# HR         analyst                          32.5
# IT         analyst                          32.5
#            associate                        60.0

# %% [markdown]
# # Challenge 2

# %% [markdown]
# #### Open the ` Fitbit.csv` file and name your dataset `fitbit`.

# %%
# above

# %% [markdown]
# #### Explore you dataset in terms of data types and descriptive statistics.
# Hint: Use Pandas functions from previous lectures.

# %%
print(fitbit.dtypes)
print(fitbit.describe())
# Out:
# Date                       object
# Calorie burned              int64
# Steps                       int64
# Distance                  float64
# Floors                      int64
# Minutes Sedentary         float64
# Minutes Lightly Active      int64
# Minutes Fairly Active       int64
# Minutes Very Active         int64
# Activity Calories           int64
# MinutesOfSleep              int64
# MinutesOfBeingAwake         int64
# NumberOfAwakings            int64
# LengthOfRestInMinutes       int64
# dtype: object
#        Calorie burned         Steps    Distance      Floors  \
# count      367.000000    367.000000  367.000000  367.000000
# mean      2741.501362  10121.588556    8.549128   11.724796
# std        916.307036   5594.836225    3.409881   10.337370
# min        179.000000      0.000000    0.000000    0.000000
# 25%       2698.000000   6730.500000    6.155000    5.000000
# 50%       2974.000000  10413.000000    8.290000   11.000000
# ...

# %%
# your answer here

# %% [markdown]
# #### You suspect that there must be a linear relationship between the Minutes Very Active and the Steps. Compute the correlation between these variables.

# %%
# Compute the correlation between Minutes Very Active and Steps
correlation = fitbit['Minutes Very Active'].corr(fitbit['Steps'])

print(f"Correlation between Minutes Very Active and Steps: {correlation}")
# Out:
# Correlation between Minutes Very Active and Steps: 0.5714518481062608

# %% [markdown]
# #### Use matplotlib to visually plot Minutes Very active vs Steps.
#
# ##### Hint : import matplotlib.pyplot as plt (See previous lessons)#####
# - Use plt.scatter(x=df['col_name_1'], y=df['col_name_2'])

# %%
# Plotting Minutes Very Active vs Steps
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
plt.scatter(fitbit['Minutes Very Active'], fitbit['Steps'])
plt.title('Minutes Very Active vs Steps')
plt.xlabel('Minutes Very Active')
plt.ylabel('Steps')
plt.grid(True)
plt.show()

# %% [markdown]
# #### What can you say about Minute Very Active and Steps? Write a comment below

# %%
# There are some dipersion in the distribution. while the linear relationship is obvious for range of data, there are certainly a lot of exceptions that fall out of distribution

# %% [markdown]
# #### We also suspect that there must be a linear relationship between the Minutes Sedentary and the Steps. Compute the correlation between these variables.

# %%
# Compute the correlation between Minutes Sedentary and Steps
correlation_sedentary_steps = fitbit['Minutes Sedentary'].corr(fitbit['Steps'])

print(f"Correlation between Minutes Sedentary and Steps: {correlation_sedentary_steps}")
# Out:
# Correlation between Minutes Sedentary and Steps: 0.07690608062990091

# %% [markdown]
# #### Use matplotlib to visually plot Minutes Sedentary vs Steps. Based on the results of the computed correlation and the plot. What can you say about these 2 variables?

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))
plt.scatter(fitbit['Minutes Sedentary'], fitbit['Steps'])
plt.title('Minutes Sedentary vs Steps')
plt.xlabel('Minutes Sedentary')
plt.ylabel('Steps')
plt.grid(True)
plt.show()

# %% [markdown]
# #### We also suspect that there must be a linear relationship between the MinutesOfSleep and the Steps. Compute the correlation between these variables.

# %%
# Compute the correlation between Minutes Sedentary and Steps
correlation_sleep_steps = fitbit['MinutesOfSleep'].corr(fitbit['Steps'])

print(f"Correlation between MinutesOfSleep and Steps: {correlation_sedentary_steps}")
# Out:
# Correlation between MinutesOfSleep and Steps: 0.07690608062990091

# %% [markdown]
# #### Use matplotlib to visually plot MinutesOfSleep vs Steps. Based on the results of the computed correlation and the plot. What can you say about these 2 variables?

# %%
plt.figure(figsize=(8, 6))
plt.scatter(fitbit['MinutesOfSleep'], fitbit['Steps'])
plt.title('MinutesOfSleep vs Steps')
plt.xlabel('MinutesOfSleep')
plt.ylabel('Steps')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Select a subset of your dataset with the columns below and compute the correlation matrix. Save the results in the variable `cor_fit`
# column= ['Calorie burned', 'Steps','Floors','Minutes Sedentary','Minutes Very Active', 'MinutesOfSleep']

# %%
# Select a subset of the dataset with specified columns
selected_columns = ['Calorie burned', 'Steps', 'Floors', 'Minutes Sedentary', 'Minutes Very Active', 'MinutesOfSleep']
subset_fitbit = fitbit[selected_columns]

# Compute the correlation matrix
cor_fit = subset_fitbit.corr()

print("Correlation Matrix:")
print(cor_fit)
# Out:
# Correlation Matrix:
#                      Calorie burned     Steps    Floors  Minutes Sedentary  \
# Calorie burned             1.000000  0.255305  0.130757           0.125353
# Steps                      0.255305  1.000000  0.306511           0.076906
# Floors                     0.130757  0.306511  1.000000           0.057812
# Minutes Sedentary          0.125353  0.076906  0.057812           1.000000
# Minutes Very Active        0.197881  0.571452  0.399503           0.105963
# MinutesOfSleep             0.011485  0.130986  0.069464           0.204242
#
#                      Minutes Very Active  MinutesOfSleep
# Calorie burned                  0.197881        0.011485
# Steps                           0.571452        0.130986
# Floors                          0.399503        0.069464
# Minutes Sedentary               0.105963        0.204242
# Minutes Very Active             1.000000        0.108018
# MinutesOfSleep                  0.108018        1.000000

# %% [markdown]
# #### Based on the result of the correlation matrix. What are the highly correlated features with the variable Steps?
# *Hint: From the results above select the variable Steps and order your results in descending order (use Pandas sort_values function)*

# %%
# Select the correlation values for the variable 'Steps'
cor_steps = cor_fit['Steps']

# Order the results in descending order
cor_steps_sorted = cor_steps.sort_values(ascending=False)

print("Correlation with Steps (descending order):")
print(cor_steps_sorted)
# Out:
# Correlation with Steps (descending order):
# Steps                  1.000000
# Minutes Very Active    0.571452
# Floors                 0.306511
# Calorie burned         0.255305
# MinutesOfSleep         0.130986
# Minutes Sedentary      0.076906
# Name: Steps, dtype: float64

# %% [markdown]
# # Challenge 3

# %% [markdown]
# #### Open the `Time_Grades.csv` file and name your dataset `time_grades`.

# %%
# done above
grades.head(5)
# Out:
#      Name  Study time  Grade
# 0    Jose           4      4
# 1   Maria           9      7
# 2   David           8      9
# 3   Sonia          10      7
# 4  Samuel          20      9

# %% [markdown]
# #### Show visually the frequency distribution of the time_grades dataset.

# %%
# Plotting the frequency distribution of the 'Time' variable
plt.figure(figsize=(8, 6))
plt.hist(grades['Study time'], bins='auto', color='blue', alpha=0.7, rwidth=0.85)
plt.title('Frequency Distribution of Time')
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# #### Is there a correlation between study time and Grade? Use both Pearson and Spearman correlation and comment your results.

# %%
# Compute Pearson correlation
pearson_corr = grades['Study time'].corr(grades['Grade'], method='pearson')

# Compute Spearman correlation
spearman_corr = grades['Study time'].corr(grades['Grade'], method='spearman')

print(f"Pearson Correlation: {pearson_corr}")
print(f"Spearman Correlation: {spearman_corr}")
# Out:
# Pearson Correlation: 0.7980456073578858
# Spearman Correlation: 0.819658753036942

# %% [markdown]
# #### Use matplotlib to visually plot Study time vs Grade. Based on the results of the computed correlation and the plot. What can you say about these 2 variables?

# %%
import seaborn as sns


# Create a scatter plot with regression line
plt.figure(figsize=(8, 6))
sns.regplot(x='Study time', y='Grade', data=grades, ci=None, line_kws={'color':'orange'})
plt.title('Study Time vs Grades')
plt.xlabel('Study Time')
plt.ylabel('Grades')
plt.grid(True)
plt.show()

# %% [markdown]
# #### Could you explain the difference between Pearson and Spearman correlation? (see References in README.md)

# %%
'''''' As oppsed to Pearson, Spearman assumes a monotonic relationship, which means that as one variable increases, 
the other variable either increases or decreases, but not necessarily at a constant rate. 
Hence Spearman can capture non-linear relationship''''''
